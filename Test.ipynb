# %%
import json
from pprint import pprint

# %%
json_data = None

with open(r'samples.json', 'r') as f:
    
    json_data = json.load(f)
    
pprint(json.dumps(json_data))
# Out:
# ('{"names": ["940", "941", "943", "944", "945", "946", "947", "948", "949", '
#  '"950", "952", "953", "954", "955", "956", "958", "959", "960", "961", "962", '
#  '"963", "964", "966", "967", "968", "969", "970", "971", "972", "973", "974", '
#  '"975", "978", "1233", "1234", "1235", "1236", "1237", "1238", "1242", '
#  '"1243", "1246", "1253", "1254", "1258", "1259", "1260", "1264", "1265", '
#  '"1273", "1275", "1276", "1277", "1278", "1279", "1280", "1281", "1282", '
#  '"1283", "1284", "1285", "1286", "1287", "1288", "1289", "1290", "1291", '
#  '"1292", "1293", "1294", "1295", "1296", "1297", "1298", "1308", "1309", '
#  '"1310", "1374", "1415", "1439", "1441", "1443", "1486", "1487", "1489", '
#  '"1490", "1491", "1494", "1495", "1497", "1499", "1500", "1501", "1502", '
#  '"1503", "1504", "1505", "1506", "1507", "1508", "1510", "1511", "1512", '
#  '"1513", "1514", "1515", "1516", "1517", "1518", "1519", "1521", "1524", '
# ...

# %%
json_data.keys()
# Out:
# dict_keys(['names', 'metadata', 'samples'])

# %%
meta_data_keys = json_data["metadata"][0]
meta_data_keys.keys()
# Out:
# dict_keys(['id', 'ethnicity', 'gender', 'age', 'location', 'bbtype', 'wfreq'])

# %%
samples_keys = json_data["samples"][0]
samples_keys.keys()
# Out:
# dict_keys(['id', 'otu_ids', 'sample_values', 'otu_labels'])
